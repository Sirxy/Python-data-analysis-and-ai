# %%
import numpy as np

# %%
# 操作视频，scikit-video
# 视频是由一张张图片组合而成的，一秒24帧此时肉眼就无法分辨，此时就是所说的视频了。

import skvideo

import skvideo.io

# %%
stars = skvideo.io.vread("./mp4/Lana Del Rey - Doin' Time.mp4")

# %%
type(stars)
# Out:
# numpy.ndarray

# %%
stars.shape
# Out:
# (6370, 432, 768, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(stars[200])  # 所以说视频是由一张张图片组合而成 + 音频--->电影

# %%
skvideo.io.vwrite("./mp4/stars.mp4", stars[:500])  # 保存前五百张图片

# %%
# 视频操作，ffmpeg合成视频，添加声音
# 视频结构，四维数组，多张图片组合而成，

# %%
import matplotlib.pyplot as plt

# %%
data = []
for i in range(1, 5553):
    img = plt.imread('./video-frame/%d.jpg'%(i))
    data.append(img)

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 5552

# %%
import numpy as np

# %%
images = np.array(data)
images.shape
# Out:
# (5552, 432, 768, 3)

# %%
skvideo.io.vwrite("./mp4/合成视频.mp4", images)

# %%
# Miley Cyrus - Slide Away
