# %%
import numpy as np
from pydub import AudioSegment

# %%
jing = AudioSegment.from_mp3("./我的唇吻不到我爱的人-王奕心.mp3")
type(jing)
# Out:
# pydub.audio_segment.AudioSegment

# %%
jing.channels
# Out:
# 2

# %%
jing.duration_seconds
# Out:
# 279.3795918367347

# %%
j1 = jing[:1000*10]
j1.duration_seconds
# Out:
# 10.0

# %%
j1
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# 分贝增加10分贝
j1 + 10
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
j1 - 10
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
sea = AudioSegment.from_mp3("./朱雅-前度.mp3")
type(sea)
# Out:
# pydub.audio_segment.AudioSegment

# %%
sea.duration_seconds
# Out:
# 213.95698412698414

# %%
# 切割音乐
s1 = sea[60*1000:70*1000]
s1
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# 组合音乐
mix = j1 + s1 
mix
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# 保存视频
AudioSegment.export(mix, "./mix_music.mp3")
# Out:
# <_io.BufferedRandom name='./mix_music.mp3'>
