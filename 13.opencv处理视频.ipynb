# %%
import numpy as np

import cv2

# 视频是多张图片组合而成的。OpenCV可以读取视频中的每一帧图片

# %%
# 使用cv2读取视频
cap = cv2.VideoCapture("./mp4/Lana Del Rey - Doin' Time.mp4")
cap  # 视频对象，图片数据，一帧帧图片数据就在cap中
# Out:
# <VideoCapture 000001BF84CDF810>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flag, frame = cap.read()
print(flag)

plt.imshow(frame)
# Out:
# True

# %%
cap.release()

# %%
1000/24
# Out:
# 41.666666666666664

# %%
cap = cv2.VideoCapture("./mp4/Lana Del Rey - Doin' Time.mp4")

flag, frame = cap.read()


index = 1
while True:
    
    if flag == False:
        break
    
    gray = cv2.cvtColor(frame, code=cv2.COLOR_BGR2GRAY)
    cv2.imshow("video", gray)  # 窗口名，frame
    
    # 将视频中的图片保存到本地
    plt.imsave("./images/%d.jpg" % (index), gray, cmap='gray')
    
    if ord("q") == cv2.waitKey(41):
        break
    flag, frame = cap.read()
    
    index += 1
# 资源释放
cv2.destroyAllWindows()
cap.release()
